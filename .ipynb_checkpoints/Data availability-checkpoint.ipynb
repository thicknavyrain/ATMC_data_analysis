# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the outdoor and indoor temperature data
outdoor_temp = pd.read_csv('./campaign_data/outdoor_temp.csv', dtype={'gps_lat_out': str, 'gps_long_out': str})
indoor_temp = pd.read_csv('./campaign_data/indoor_temp.csv', dtype={'gps_lat_in': str, 'gps_long_in': str})

# Convert 'Date/Time' to datetime format
outdoor_temp['Date/Time'] = pd.to_datetime(outdoor_temp['Date/Time'])
indoor_temp['Date/Time'] = pd.to_datetime(indoor_temp['Date/Time'])

# Set 'Date/Time' as the index
outdoor_temp.set_index('Date/Time', inplace=True)
indoor_temp.set_index('Date/Time', inplace=True)

# Add a column to indicate valid data
outdoor_temp['valid'] = 1
indoor_temp['valid'] = 1

# Resample to daily frequency and count the number of valid data points per day
outdoor_daily = outdoor_temp.groupby('sensor_id_outdoor_temp').resample('D')['valid'].sum().reset_index()
indoor_daily = indoor_temp.groupby('sensor_id_indoor_temp').resample('D')['valid'].sum().reset_index()

# Calculate the total number of days in the deployment period for each sensor
outdoor_deployment = outdoor_daily.groupby('sensor_id_outdoor_temp').agg(
    start_date=('Date/Time', 'min'),
    end_date=('Date/Time', 'max')
)
outdoor_deployment['total_days'] = (outdoor_deployment['end_date'] - outdoor_deployment['start_date']).dt.days + 1

indoor_deployment = indoor_daily.groupby('sensor_id_indoor_temp').agg(
    start_date=('Date/Time', 'min'),
    end_date=('Date/Time', 'max')
)
indoor_deployment['total_days'] = (indoor_deployment['end_date'] - indoor_deployment['start_date']).dt.days + 1

# Calculate the number of valid days
outdoor_valid_days = outdoor_daily[outdoor_daily['valid'] > 0].groupby('sensor_id_outdoor_temp').size()
indoor_valid_days = indoor_daily[indoor_daily['valid'] > 0].groupby('sensor_id_indoor_temp').size()

# Combine the results into a single DataFrame for plotting
outdoor_results = outdoor_deployment.join(outdoor_valid_days.rename('valid_days')).fillna(0)
outdoor_results['invalid_days'] = outdoor_results['total_days'] - outdoor_results['valid_days']
outdoor_results.sort_values(by='valid_days', ascending=False, inplace=True)

indoor_results = indoor_deployment.join(indoor_valid_days.rename('valid_days')).fillna(0)
indoor_results['invalid_days'] = indoor_results['total_days'] - indoor_results['valid_days']
indoor_results.sort_values(by='valid_days', ascending=False, inplace=True)

# Calculate statistics for outdoor sensors
outdoor_median_duration = outdoor_results['total_days'].median()
outdoor_25th_percentile_duration = outdoor_results['total_days'].quantile(0.25)
outdoor_75th_percentile_duration = outdoor_results['total_days'].quantile(0.75)

outdoor_valid_fraction = outdoor_results['valid_days'] / outdoor_results['total_days']
outdoor_median_fraction_valid = outdoor_valid_fraction.median()
outdoor_25th_percentile_fraction_valid = outdoor_valid_fraction.quantile(0.25)
outdoor_75th_percentile_fraction_valid = outdoor_valid_fraction.quantile(0.75)
outdoor_mean_fraction_valid = outdoor_valid_fraction.mean()
outdoor_std_fraction_valid = outdoor_valid_fraction.std()

# Calculate statistics for indoor sensors
indoor_median_duration = indoor_results['total_days'].median()
indoor_25th_percentile_duration = indoor_results['total_days'].quantile(0.25)
indoor_75th_percentile_duration = indoor_results['total_days'].quantile(0.75)

indoor_valid_fraction = indoor_results['valid_days'] / indoor_results['total_days']
indoor_median_fraction_valid = indoor_valid_fraction.median()
indoor_25th_percentile_fraction_valid = indoor_valid_fraction.quantile(0.25)
indoor_75th_percentile_fraction_valid = indoor_valid_fraction.quantile(0.75)
indoor_mean_fraction_valid = indoor_valid_fraction.mean()
indoor_std_fraction_valid = indoor_valid_fraction.std()

# Print the results
print(f"Outdoor sensors: Median duration = {outdoor_median_duration} days, 25th percentile = {outdoor_25th_percentile_duration} days, 75th percentile = {outdoor_75th_percentile_duration} days")
print(f"Outdoor sensors: Median fraction operational = {outdoor_median_fraction_valid * 100:.2f}%, 25th percentile = {outdoor_25th_percentile_fraction_valid * 100:.2f}%, 75th percentile = {outdoor_75th_percentile_fraction_valid * 100:.2f}%, mean = {outdoor_mean_fraction_valid * 100:.2f}%, std = {outdoor_std_fraction_valid * 100:.2f}%")
print(f"Indoor sensors: Median duration = {indoor_median_duration} days, 25th percentile = {indoor_25th_percentile_duration} days, 75th percentile = {indoor_75th_percentile_duration} days")
print(f"Indoor sensors: Median fraction operational = {indoor_median_fraction_valid * 100:.2f}%, 25th percentile = {indoor_25th_percentile_fraction_valid * 100:.2f}%, 75th percentile = {indoor_75th_percentile_fraction_valid * 100:.2f}%, mean = {indoor_mean_fraction_valid * 100:.2f}%, std = {indoor_std_fraction_valid * 100:.2f}%")

# Format the results into the statement
statement = (
    f"Households participated for a median duration of {outdoor_median_duration} days (outdoor, 25th percentile = {outdoor_25th_percentile_duration} days, 75th percentile = {outdoor_75th_percentile_duration} days) "
    f"and {indoor_median_duration} days (indoor, 25th percentile = {indoor_25th_percentile_duration} days, 75th percentile = {indoor_75th_percentile_duration} days). "
    f"Sensors captured continuous data coverage for a median of {outdoor_median_fraction_valid * 100:.2f}% (outdoor, 25th percentile = {outdoor_25th_percentile_fraction_valid * 100:.2f}%, 75th percentile = {outdoor_75th_percentile_fraction_valid * 100:.2f}%, mean = {outdoor_mean_fraction_valid * 100:.2f}%, std = {outdoor_std_fraction_valid * 100:.2f}%) "
    f"and {indoor_median_fraction_valid * 100:.2f}% (indoor, 25th percentile = {indoor_25th_percentile_fraction_valid * 100:.2f}%, 75th percentile = {indoor_75th_percentile_fraction_valid * 100:.2f}%, mean = {indoor_mean_fraction_valid * 100:.2f}%, std = {indoor_std_fraction_valid * 100:.2f}%) "
    f"of their deployment time on average, ensuring good coverage in comparable homes across seasonal trends."
)

print(statement)

# Plot the results
fig, axes = plt.subplots(2, 1, figsize=(20, 10))

# Plot outdoor sites
axes[0].bar(outdoor_results.index, outdoor_results['invalid_days'], color='grey', label='Inactive Days', hatch='//')
axes[0].bar(outdoor_results.index, outdoor_results['valid_days'], bottom=outdoor_results['invalid_days'], color='darkorange', label='Operational Days')
axes[0].set_ylabel('Number of Days')
axes[0].set_title('Outdoor Sites Data Availability')
axes[0].legend()
axes[0].set_xlabel('Temperature Sensor')
axes[0].set_xticks(np.arange(0, len(outdoor_results), step=1))
axes[0].set_xticklabels(outdoor_results.index[::1], rotation=90, ha='right')

# Plot indoor sites
axes[1].bar(indoor_results.index, indoor_results['invalid_days'], color='grey', label='Inactive Days', hatch='//')
axes[1].bar(indoor_results.index, indoor_results['valid_days'], bottom=indoor_results['invalid_days'], color='darkorange', label='Operational Days')
axes[1].set_ylabel('Number of Days')
axes[1].set_title('Indoor Sites Data Availability')
axes[1].legend()
axes[1].set_xlabel('Temperature Sensor')
axes[1].set_xticks(np.arange(0, len(indoor_results), step=1))
axes[1].set_xticklabels(indoor_results.index[::1], rotation=90, ha='right')

plt.tight_layout()
plt.savefig('paper_plots/data_availability/data_availability_by_sensor_ordered.png', bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_13197/3488677324.py:6: DtypeWarning: Columns (7,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   outdoor_temp = pd.read_csv('./campaign_data/outdoor_temp.csv', dtype={'gps_lat_out': str, 'gps_long_out': str})
# /tmp/ipykernel_13197/3488677324.py:7: DtypeWarning: Columns (7,8,11,12,13,25,33,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   indoor_temp = pd.read_csv('./campaign_data/indoor_temp.csv', dtype={'gps_lat_in': str, 'gps_long_in': str})
# Outdoor sensors: Median duration = 316.0 days, 25th percentile = 253.0 days, 75th percentile = 331.0 days
# Outdoor sensors: Median fraction operational = 100.00%, 25th percentile = 96.87%, 75th percentile = 100.00%, mean = 96.14%, std = 8.19%
# Indoor sensors: Median duration = 321.5 days, 25th percentile = 254.25 days, 75th percentile = 413.0 days
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the outdoor and indoor humidity data
outdoor_hum = pd.read_csv('./campaign_data/outdoor_hum.csv', dtype={'gps_lat_out': str, 'gps_long_out': str})
indoor_hum = pd.read_csv('./campaign_data/indoor_hum.csv', dtype={'gps_lat_in': str, 'gps_long_in': str})

# Convert 'Date/Time' to datetime format
outdoor_hum['Date/Time'] = pd.to_datetime(outdoor_hum['Date/Time'])
indoor_hum['Date/Time'] = pd.to_datetime(indoor_hum['Date/Time'])

# Set 'Date/Time' as the index
outdoor_hum.set_index('Date/Time', inplace=True)
indoor_hum.set_index('Date/Time', inplace=True)

# Add a column to indicate valid data
outdoor_hum['valid'] = 1
indoor_hum['valid'] = 1

# Resample to daily frequency and count the number of valid data points per day
outdoor_daily = outdoor_hum.groupby('sensor_id_outdoor_hum').resample('D')['valid'].sum().reset_index()
indoor_daily = indoor_hum.groupby('sensor_id_indoor_hum').resample('D')['valid'].sum().reset_index()

# Calculate the total number of days in the deployment period for each sensor
outdoor_deployment = outdoor_daily.groupby('sensor_id_outdoor_hum').agg(
    start_date=('Date/Time', 'min'),
    end_date=('Date/Time', 'max')
)
outdoor_deployment['total_days'] = (outdoor_deployment['end_date'] - outdoor_deployment['start_date']).dt.days + 1

indoor_deployment = indoor_daily.groupby('sensor_id_indoor_hum').agg(
    start_date=('Date/Time', 'min'),
    end_date=('Date/Time', 'max')
)
indoor_deployment['total_days'] = (indoor_deployment['end_date'] - indoor_deployment['start_date']).dt.days + 1

# Calculate the number of valid days
outdoor_valid_days = outdoor_daily[outdoor_daily['valid'] > 0].groupby('sensor_id_outdoor_hum').size()
indoor_valid_days = indoor_daily[indoor_daily['valid'] > 0].groupby('sensor_id_indoor_hum').size()

# Combine the results into a single DataFrame for plotting
outdoor_results = outdoor_deployment.join(outdoor_valid_days.rename('valid_days')).fillna(0)
outdoor_results['invalid_days'] = outdoor_results['total_days'] - outdoor_results['valid_days']
outdoor_results.sort_values(by='valid_days', ascending=False, inplace=True)

indoor_results = indoor_deployment.join(indoor_valid_days.rename('valid_days')).fillna(0)
indoor_results['invalid_days'] = indoor_results['total_days'] - indoor_results['valid_days']
indoor_results.sort_values(by='valid_days', ascending=False, inplace=True)

# Calculate statistics for outdoor sensors
outdoor_median_duration = outdoor_results['total_days'].median()
outdoor_25th_percentile_duration = outdoor_results['total_days'].quantile(0.25)
outdoor_75th_percentile_duration = outdoor_results['total_days'].quantile(0.75)

outdoor_valid_fraction = outdoor_results['valid_days'] / outdoor_results['total_days']
outdoor_median_fraction_valid = outdoor_valid_fraction.median()
outdoor_25th_percentile_fraction_valid = outdoor_valid_fraction.quantile(0.25)
outdoor_75th_percentile_fraction_valid = outdoor_valid_fraction.quantile(0.75)
outdoor_mean_fraction_valid = outdoor_valid_fraction.mean()
outdoor_std_fraction_valid = outdoor_valid_fraction.std()

# Calculate statistics for indoor sensors
indoor_median_duration = indoor_results['total_days'].median()
indoor_25th_percentile_duration = indoor_results['total_days'].quantile(0.25)
indoor_75th_percentile_duration = indoor_results['total_days'].quantile(0.75)

indoor_valid_fraction = indoor_results['valid_days'] / indoor_results['total_days']
indoor_median_fraction_valid = indoor_valid_fraction.median()
indoor_25th_percentile_fraction_valid = indoor_valid_fraction.quantile(0.25)
indoor_75th_percentile_fraction_valid = indoor_valid_fraction.quantile(0.75)
indoor_mean_fraction_valid = indoor_valid_fraction.mean()
indoor_std_fraction_valid = indoor_valid_fraction.std()

# Print the results
print(f"Outdoor humidity sensors: Median duration = {outdoor_median_duration} days, 25th percentile = {outdoor_25th_percentile_duration} days, 75th percentile = {outdoor_75th_percentile_duration} days")
print(f"Outdoor humidity sensors: Median fraction operational = {outdoor_median_fraction_valid * 100:.2f}%, 25th percentile = {outdoor_25th_percentile_fraction_valid * 100:.2f}%, 75th percentile = {outdoor_75th_percentile_fraction_valid * 100:.2f}%, mean = {outdoor_mean_fraction_valid * 100:.2f}%, std = {outdoor_std_fraction_valid * 100:.2f}%")
print(f"Indoor humidity sensors: Median duration = {indoor_median_duration} days, 25th percentile = {indoor_25th_percentile_duration} days, 75th percentile = {indoor_75th_percentile_duration} days")
print(f"Indoor humidity sensors: Median fraction operational = {indoor_median_fraction_valid * 100:.2f}%, 25th percentile = {indoor_25th_percentile_fraction_valid * 100:.2f}%, 75th percentile = {indoor_75th_percentile_fraction_valid * 100:.2f}%, mean = {indoor_mean_fraction_valid * 100:.2f}%, std = {indoor_std_fraction_valid * 100:.2f}%")

# Format the results into the statement
statement = (
    f"Households participated for a median duration of {outdoor_median_duration} days (outdoor, 25th percentile = {outdoor_25th_percentile_duration} days, 75th percentile = {outdoor_75th_percentile_duration} days) "
    f"and {indoor_median_duration} days (indoor, 25th percentile = {indoor_25th_percentile_duration} days, 75th percentile = {indoor_75th_percentile_duration} days). "
    f"Sensors captured continuous data coverage for a median of {outdoor_median_fraction_valid * 100:.2f}% (outdoor, 25th percentile = {outdoor_25th_percentile_fraction_valid * 100:.2f}%, 75th percentile = {outdoor_75th_percentile_fraction_valid * 100:.2f}%, mean = {outdoor_mean_fraction_valid * 100:.2f}%, std = {outdoor_std_fraction_valid * 100:.2f}%) "
    f"and {indoor_median_fraction_valid * 100:.2f}% (indoor, 25th percentile = {indoor_25th_percentile_fraction_valid * 100:.2f}%, 75th percentile = {indoor_75th_percentile_fraction_valid * 100:.2f}%, mean = {indoor_mean_fraction_valid * 100:.2f}%, std = {indoor_std_fraction_valid * 100:.2f}%) "
    f"of their deployment time on average, ensuring good coverage in comparable homes across seasonal trends."
)

print(statement)

# Plot the results
fig, axes = plt.subplots(2, 1, figsize=(20, 10))

# Plot outdoor sites
axes[0].bar(outdoor_results.index, outdoor_results['invalid_days'], color='grey', label='Inactive Days', hatch='//')
axes[0].bar(outdoor_results.index, outdoor_results['valid_days'], bottom=outdoor_results['invalid_days'], color='darkorange', label='Operational Days')
axes[0].set_ylabel('Number of Days')
axes[0].set_title('Outdoor Humidity Sensors Data Availability')
axes[0].legend()
axes[0].set_xlabel('Humidity Sensor')
axes[0].set_xticks(np.arange(0, len(outdoor_results), step=1))
axes[0].set_xticklabels(outdoor_results.index[::1], rotation=90, ha='right')

# Plot indoor sites
axes[1].bar(indoor_results.index, indoor_results['invalid_days'], color='grey', label='Inactive Days', hatch='//')
axes[1].bar(indoor_results.index, indoor_results['valid_days'], bottom=indoor_results['invalid_days'], color='darkorange', label='Operational Days')
axes[1].set_ylabel('Number of Days')
axes[1].set_title('Indoor Humidity Sensors Data Availability')
axes[1].legend()
axes[1].set_xlabel('Humidity Sensor')
axes[1].set_xticks(np.arange(0, len(indoor_results), step=1))
axes[1].set_xticklabels(indoor_results.index[::1], rotation=90, ha='right')

plt.tight_layout()
plt.savefig('paper_plots/data_availability/hum_data_availability_by_sensor_ordered.png', bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_13197/3672742354.py:6: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   outdoor_hum = pd.read_csv('./campaign_data/outdoor_hum.csv', dtype={'gps_lat_out': str, 'gps_long_out': str})
# /tmp/ipykernel_13197/3672742354.py:7: DtypeWarning: Columns (8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   indoor_hum = pd.read_csv('./campaign_data/indoor_hum.csv', dtype={'gps_lat_in': str, 'gps_long_in': str})
# Outdoor humidity sensors: Median duration = 400.0 days, 25th percentile = 263.5 days, 75th percentile = 403.5 days
# Outdoor humidity sensors: Median fraction operational = 74.46%, 25th percentile = 71.29%, 75th percentile = 76.31%, mean = 74.00%, std = 7.67%
# Indoor humidity sensors: Median duration = 171.0 days, 25th percentile = 94.0 days, 75th percentile = 189.5 days
# ...
